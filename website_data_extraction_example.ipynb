# %%
import pandas as pd
baseball = pd.read_html('https://www.baseball-reference.com/leagues/MLB/2019-standard-batting.shtml')
len(baseball)
# Out:
# 1

# %%
bb_df = baseball[0]
bb_df.head()
# Out:
#                      Tm #Bat BatAge   R/G    G    PA    AB    R     H   2B  \
# 0  Arizona Diamondbacks   45   28.7  5.02  162  6315  5633  813  1419  288
# 1        Atlanta Braves   50   28.0  5.28  162  6302  5560  855  1432  277
# 2     Baltimore Orioles   58   26.5  4.50  162  6189  5596  729  1379  252
# 3        Boston Red Sox   47   27.3  5.56  162  6475  5770  901  1554  345
# 4          Chicago Cubs   52   27.7  5.02  162  6195  5461  814  1378  270
#
#    ...   SLG   OPS OPS+    TB  GDP HBP  SH  SF IBB   LOB
# 0  ...  .434  .757   94  2447  120  70  31  40  36  1119
# 1  ...  .452  .789   98  2514  104  60  25  35  39  1138
# 2  ...  .415  .725   90  2320  111  71  22  37   8  1063
# 3  ...  .466  .806  106  2688  127  49  20  44  36  1170
# 4  ...  .452  .783  102  2468  127  83  30  39  33  1071
#
# [5 rows x 29 columns]

# %%
bb_df[0]["Age"] = bb_df[0]["Age"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...
